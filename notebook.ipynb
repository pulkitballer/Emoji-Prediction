# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Comment-Emoji Dataset.csv')
data
# Out:
#        Unnamed: 0                                               TEXT  Label
# 0               0  Vacation wasted ! #vacation2017 #photobomb #ti...      0
# 1               1  Oh Wynwood, you’re so funny! : @user #Wynwood ...      1
# 2               2  Been friends since 7th grade. Look at us now w...      2
# 3               3  This is what it looks like when someone loves ...      3
# 4               4  RT @user this white family was invited to a Bl...      3
# ...           ...                                                ...    ...
# 69995       69995  Yes, I call Galina "my Bubie" Go follow my bea...      3
# 69996       69996    I SEA you, Seattle @ Ballard Seafood Festival\n     16
# 69997       69997  If one of my daughters is wearing this and ask...      2
# 69998       69998  Guess who whoop people on THEIR homecoming?! #...      3
# 69999       69999  We Love you Robbie @ Heritage Memorial Cemeter...     14
#
# [70000 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X = data['TEXT']
Y = data['Label']

# %%
X_train , X_test , Y_train , Y_test = train_test_split(X,Y, random_state=5,test_size=0.3)

# %%
X.shape, Y.shape, mappings.shape
# Out:
# ((70000,), (70000,), (20, 3))

# %%
mappings = pd.read_csv("emoji-mapping.csv")
mappings.head()
# Out:
#    Unnamed: 0 emoticons  number
# 0           0         😜       0
# 1           1         📸       1
# 2           2         😍       2
# 3           3         😂       3
# 4           4         😉       4

# %%
from nltk.corpus import stopwords

# %%
stop_words = stopwords.words("english")
stop_words[:5]
# Out:
# ['i', 'me', 'my', 'myself', 'we']

# %%
def tokenize(tweets):
    stop_words = stopwords.words("english")
    tokenized_tweets = []
    for tweet in tweets:
        words = tweet.split(" ")
        tokenized_string = ""
        for word in words:
            if word[0] != '@' and word not in stop_words:
                if word[0] == "#":
                    word = word[1:]
                tokenized_string += word + " "
        tokenized_tweets.append(tokenized_string)
    return tokenized_tweets

# %%
def encod_tweets(tweets):
    tokenizer = Tokenizer(filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', split=" ", lower=True)
    tokenizer.fit_on_texts(tweets)
    return tokenizer, tokenizer.texts_to_sequences(tweets)

# %%
def format_data(encoded_tweets, max_length, labels):
    x = pad_sequences(encoded_tweets, maxlen= max_length, padding='post')
    y = []
    for emoji in labels:
        bit_vec = np.zeros(20)
        bit_vec[emoji] = 1
        y.append(bit_vec)
    y = np.asarray(y)
    return x, y

# %%
def create_weight_matrix(vocab, raw_embeddings):
    vocab_size = len(vocab) + 1
    weight_matrix = np.zeros((vocab_size, 300))
    for word, idx in vocab.items():
        if word in raw_embeddings:
            weight_matrix[idx] = raw_embeddings[word]
    return weight_matrix

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Bidirectional
from keras.layers import Embedding
from keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
def final_model(weight_matrix, vocab_size, max_length, x, y, epochs = 5):
    embedding_layer = Embedding(vocab_size, 300, weights=[weight_matrix], input_length=max_length, trainable=True, mask_zero=True)
    model = Sequential()
    model.add(embedding_layer)
    model.add(Bidirectional(LSTM(128, dropout=0.2, return_sequences=True)))
    model.add(Bidirectional(LSTM(128, dropout=0.2)))
    model.add(Dense(20, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(x, y, epochs = epochs, validation_split = 0.25)
    score, acc = model.evaluate(x_test, y_test)
    return model, score, acc

# %%
import math

# %%
tokenized_tweets = tokenize(X_train)
tokenized_tweets += tokenize(X_test)
max_length = math.ceil(sum([len(s.split(" ")) for s in tokenized_tweets])/len(tokenized_tweets))
tokenizer, encoded_tweets = encod_tweets(tokenized_tweets)
max_length, len(tokenized_tweets)
# Out:
# (10, 70000)

# %%
train_length = X_train.shape[0]
test_length = X_test.shape[0]
train_length, test_length
# Out:
# (49000, 21000)

# %%
x, y = format_data(encoded_tweets[:train_length], max_length, Y_train)
len(x), len(y)
# Out:
# (49000, 49000)

# %%
x_test, y_test = format_data(encoded_tweets[train_length:], max_length, Y_test)
len(x_test), len(y_test)
# Out:
# (21000, 21000)

# %%
vocab = tokenizer.word_index
vocab, len(vocab)
# Out:
# ({'i': 1,
#   '️': 2,
#   'love': 3,
#   'the': 4,
#   '…': 5,
#   'new': 6,
#   'amp': 7,
#   'happy': 8,
#   'day': 9,
#   'my': 10,
#   'one': 11,
#   'night': 12,
#   'york': 13,
#   'time': 14,
#   'this': 15,
#   'beach': 16,
#   'today': 17,
#   'good': 18,
#   'park': 19,
#   'christmas': 20,
#   'you': 21,
#   'best': 22,
#   'like': 23,
#   "i'm": 24,
#   'california': 25,
#   'get': 26,
#   'we': 27,
#   'a': 28,
#   'birthday': 29,
#   'last': 30,
#   'got': 31,
#   'city': 32,
#   'beautiful': 33,
#   'great': 34,
#   'little': 35,
#   'see': 36,
#   'family': 37,
#   'university': 38,
#   'thanks': 39,
#   'back': 40,
#   'thank': 41,
#   'life': 42,
#   'so': 43,
#   'fun': 44,
#   'it': 45,
#   'much': 46,
#   'me': 47,
#   'favorite': 48,
#   'center': 49,
#   'first': 50,
#   'when': 51,
#   'morning': 52,
#   'home': 53,
#   'always': 54,
#   'tonight': 55,
#   'go': 56,
#   'us': 57,
#   'friends': 58,
#   'weekend': 59,
#   'florida': 60,
#   'amazing': 61,
#   'texas': 62,
#   'year': 63,
#   "it's": 64,
#   'lake': 65,
#   'girl': 66,
#   'know': 67,
#   'come': 68,
#   'school': 69,
#   'look': 70,
#   'in': 71,
#   'nyc': 72,
#   'state': 73,
#   "can't": 74,
#   'and': 75,
#   'just': 76,
#   'people': 77,
#   'repost': 78,
#   'at': 79,
#   'world': 80,
#   'baby': 81,
#   'san': 82,
#   '2': 83,
#   'place': 84,
#   'w': 85,
#   'house': 86,
#   'high': 87,
#   'friend': 88,
#   'make': 89,
#   'two': 90,
#   'work': 91,
#   'los': 92,
#   'big': 93,
#   'never': 94,
#   'south': 95,
#   '1': 96,
#   'all': 97,
#   'angeles': 98,
#   'way': 99,
#   'chicago': 100,
#   'still': 101,
#   'show': 102,
#   'right': 103,
#   'miami': 104,
#   'the…': 105,
#   'lol': 106,
#   'made': 107,
#   'what': 108,
#   'days': 109,
#   'heart': 110,
#   'miss': 111,
#   'better': 112,
#   'another': 113,
#   'ever': 114,
#   'bar': 115,
#   'take': 116,
#   'summer': 117,
#   'ready': 118,
#   'girls': 119,
#   'week': 120,
#   'vegas': 121,
#   'north': 122,
#   'tbt': 123,
#   'u': 124,
#   'photo': 125,
#   'on': 126,
#   'music': 127,
#   'merry': 128,
#   'la': 129,
#   'now': 130,
#   'downtown': 131,
#   'going': 132,
#   'sunday': 133,
#   'live': 134,
#   'up': 135,
#   'carolina': 136,
#   'thankful': 137,
#   'next': 138,
#   'man': 139,
#   'party': 140,
#   'to': 141,
#   'hair': 142,
#   'getting': 143,
#   'friday': 144,
#   'wait': 145,
#   'years': 146,
#   'stadium': 147,
#   'art': 148,
#   'dinner': 149,
#   '3': 150,
#   'lit': 151,
#   'washington': 152,
#   'out': 153,
#   'pretty': 154,
#   'date': 155,
#   'club': 156,
#   'ohio': 157,
#   '2017': 158,
#   'old': 159,
#   'even': 160,
#   'view': 161,
#   'oh': 162,
#   'here': 163,
#   'no': 164,
#   'game': 165,
#   'everyone': 166,
#   'perfect': 167,
#   'georgia': 168,
#   'finally': 169,
#   'coming': 170,
#   'usa': 171,
#   'sweet': 172,
#   'want': 173,
#   'really': 174,
#   'if': 175,
#   'need': 176,
#   'county': 177,
#   'say': 178,
#   'brooklyn': 179,
#   'hollywood': 180,
#   's': 181,
#   'that': 182,
#   'saturday': 183,
#   'island': 184,
#   'las': 185,
#   'college': 186,
#   'disney': 187,
#   'long': 188,
#   'is': 189,
#   'guys': 190,
#   'hot': 191,
#   'think': 192,
#   'had': 193,
#   'ny': 194,
#   'guy': 195,
#   'boy': 196,
#   'check': 197,
#   'west': 198,
#   'times': 199,
#   'with': 200,
#   'hope': 201,
#   'st': 202,
#   'mom': 203,
#   'of': 204,
#   'fire': 205,
#   'every': 206,
#   'our': 207,
#   'it’s': 208,
#   'coffee': 209,
#   'wedding': 210,
#   'cute': 211,
#   "i've": 212,
#   'square': 213,
#   'for': 214,
#   'magic': 215,
#   'picture': 216,
#   'things': 217,
#   'awesome': 218,
#   'houston': 219,
#   '5': 220,
#   'these': 221,
#   'well': 222,
#   'looking': 223,
#   'n': 224,
#   'making': 225,
#   '4': 226,
#   'real': 227,
#   'and…': 228,
#   'national': 229,
#   'hotel': 230,
#   'atlanta': 231,
#   'post': 232,
#   'blue': 233,
#   'cool': 234,
#   'god': 235,
#   'red': 236,
#   'church': 237,
#   'proud': 238,
#   'sunset': 239,
#   'street': 240,
#   'could': 241,
#   'tree': 242,
#   'keep': 243,
#   'she': 244,
#   'food': 245,
#   'airport': 246,
#   'tomorrow': 247,
#   'sun': 248,
#   'white': 249,
#   'pic': 250,
#   'i’m': 251,
#   'full': 252,
#   'soon': 253,
#   'link': 254,
#   'e': 255,
#   'beauty': 256,
#   'restaurant': 257,
#   'together': 258,
#   'of…': 259,
#   'fall': 260,
#   'lunch': 261,
#   'came': 262,
#   'to…': 263,
#   'holiday': 264,
#   'jersey': 265,
#   '•': 266,
#   'blessed': 267,
#   'toronto': 268,
#   "y'all": 269,
#   'everything': 270,
#   'o': 271,
#   'let': 272,
#   'excited': 273,
#   'ca': 274,
#   'season': 275,
#   'selfie': 276,
#   't': 277,
#   '4th': 278,
#   'ya': 279,
#   'america': 280,
#   'around': 281,
#   'resort': 282,
#   'rock': 283,
#   'nice': 284,
#   'yesterday': 285,
#   'smile': 286,
#   'video': 287,
#   'michigan': 288,
#   'stop': 289,
#   'nothing': 290,
#   "we're": 291,
#   'feel': 292,
#   'international': 293,
#   'ladies': 294,
#   'monday': 295,
#   'museum': 296,
#   "don't": 297,
#   'virginia': 298,
#   'he': 299,
#   'forever': 300,
#   "that's": 301,
#   'do': 302,
#   "i'll": 303,
#   'sure': 304,
#   'trip': 305,
#   'yes': 306,
#   'missing': 307,
#   'hall': 308,
#   'grand': 309,
#   'kids': 310,
#   'be': 311,
#   'start': 312,
#   'town': 313,
#   'not': 314,
#   'free': 315,
#   'hard': 316,
#   'face': 317,
#   'would': 318,
#   'thing': 319,
#   'tennessee': 320,
#   'fam': 321,
#   'gonna': 322,
#   '️…': 323,
#   'how': 324,
#   'team': 325,
#   'dallas': 326,
#   'dance': 327,
#   'loves': 328,
#   'east': 329,
#   'but': 330,
#   'santa': 331,
#   'taking': 332,
#   'many': 333,
#   'orlando': 334,
#   'crazy': 335,
#   'sister': 336,
#   'by': 337,
#   'en': 338,
#   'shop': 339,
#   'central': 340,
#   'ontario': 341,
#   'illinois': 342,
#   'wonderful': 343,
#   'field': 344,
#   'bio': 345,
#   'makes': 346,
#   'found': 347,
#   'they': 348,
#   'gorgeous': 349,
#   'glad': 350,
#   'shit': 351,
#   'boston': 352,
#   'district': 353,
#   'lil': 354,
#   'b': 355,
#   'took': 356,
#   '10': 357,
#   'boys': 358,
#   'special': 359,
#   'may': 360,
#   'july': 361,
#   'austin': 362,
#   'fort': 363,
#   'celebrating': 364,
#   'disneyland': 365,
#   'meet': 366,
#   'shot': 367,
#   'room': 368,
#   'studio': 369,
#   'top': 370,
#   'nashville': 371,
#   'end': 372,
#   'already': 373,
#   'seattle': 374,
#   'call': 375,
#   "disney's": 376,
#   'grill': 377,
#   'garden': 378,
#   'side': 379,
#   'looks': 380,
#   'super': 381,
#   'hills': 382,
#   '6': 383,
#   'diego': 384,
#   'part': 385,
#   'loving': 386,
#   'loved': 387,
#   'fitness': 388,
#   'there': 389,
#   'lovely': 390,
#   'your': 391,
#   'breakfast': 392,
#   'kingdom': 393,
#   'cafe': 394,
#   'newyork': 395,
#   'francisco': 396,
#   'have': 397,
#   'l': 398,
#   'bad': 399,
#   'manhattan': 400,
#   'working': 401,
#   'black': 402,
#   'said': 403,
#   'stay': 404,
#   'lounge': 405,
#   '7': 406,
#   '9': 407,
#   'feeling': 408,
#   'play': 409,
#   'river': 410,
#   'bae': 411,
#   'something': 412,
#   '11': 413,
#   'lot': 414,
#   "let's": 415,
#   'thanksgiving': 416,
#   'true': 417,
#   'c': 418,
#   'moment': 419,
#   '2016': 420,
#   'hey': 421,
#   'arizona': 422,
#   'a…': 423,
#   'welcome': 424,
#   'country': 425,
#   'again': 426,
#   'pennsylvania': 427,
#   'who': 428,
#   'fl': 429,
#   'bridge': 430,
#   'studios': 431,
#   'bay': 432,
#   'give': 433,
#   'gotta': 434,
#   'holidays': 435,
#   'person': 436,
#   'from': 437,
#   'someone': 438,
#   'r': 439,
#   'class': 440,
#   'colorado': 441,
#   'walk': 442,
#   'mountain': 443,
#   'light': 444,
#   'photography': 445,
#   'seeing': 446,
#   'market': 447,
#   'enjoying': 448,
#   'for…': 449,
#   '2018': 450,
#   'lights': 451,
#   'd': 452,
#   'find': 453,
#   'babe': 454,
#   'weather': 455,
#   'point': 456,
#   '8': 457,
#   'tell': 458,
#   'throwback': 459,
#   'since': 460,
#   'set': 461,
#   'went': 462,
#   'vibes': 463,
#   'worth': 464,
#   'visit': 465,
#   'early': 466,
#   'done': 467,
#   'please': 468,
#   'adventure': 469,
#   'brother': 470,
#   'put': 471,
#   'follow': 472,
#   'hill': 473,
#   'some': 474,
#   'without': 475,
#   'united': 476,
#   'dad': 477,
#   'believe': 478,
#   'guess': 479,
#   'enjoy': 480,
#   'too': 481,
#   'springs': 482,
#   'away': 483,
#   'whole': 484,
#   'more': 485,
#   'x': 486,
#   "he's": 487,
#   'hello': 488,
#   'i…': 489,
#   'ice': 490,
#   'halloween': 491,
#   'theatre': 492,
#   'arena': 493,
#   'missed': 494,
#   'only': 495,
#   'valley': 496,
#   'though': 497,
#   'almost': 498,
#   'style': 499,
#   'also': 500,
#   'zoo': 501,
#   'm': 502,
#   'falls': 503,
#   'you…': 504,
#   'dream': 505,
#   'lady': 506,
#   'p': 507,
#   'indiana': 508,
#   'co': 509,
#   'open': 510,
#   'kentucky': 511,
#   'run': 512,
#   'massachusetts': 513,
#   'dog': 514,
#   'shoot': 515,
#   'ago': 516,
#   'village': 517,
#   'watching': 518,
#   'american': 519,
#   'playing': 520,
#   'sometimes': 521,
#   'late': 522,
#   'wanna': 523,
#   'off': 524,
#   'fashion': 525,
#   'waiting': 526,
#   'trying': 527,
#   'at…': 528,
#   'fav': 529,
#   'hit': 530,
#   'model': 531,
#   'festival': 532,
#   'tx': 533,
#   '12': 534,
#   'shopping': 535,
#   'left': 536,
#   'watch': 537,
#   'event': 538,
#   'my…': 539,
#   'nights': 540,
#   'maryland': 541,
#   'grateful': 542,
#   'spend': 543,
#   'congrats': 544,
#   'brunch': 545,
#   'farm': 546,
#   'head': 547,
#   'three': 548,
#   'concert': 549,
#   'sunshine': 550,
#   "ain't": 551,
#   'wish': 552,
#   'company': 553,
#   'support': 554,
#   'color': 555,
#   'building': 556,
#   'sky': 557,
#   'fair': 558,
#   'couple': 559,
#   'pictures': 560,
#   'spring': 561,
#   'remember': 562,
#   'memorial': 563,
#   'met': 564,
#   'because': 565,
#   'alabama': 566,
#   'bday': 567,
#   'arts': 568,
#   'dc': 569,
#   'eve': 570,
#   'sisters': 571,
#   'walt': 572,
#   'dress': 573,
#   'song': 574,
#   'creek': 575,
#   'in…': 576,
#   'lucky': 577,
#   'else': 578,
#   'store': 579,
#   'wcw': 580,
#   'f': 581,
#   'funny': 582,
#   'months': 583,
#   'im': 584,
#   'eyes': 585,
#   'young': 586,
#   'tho': 587,
#   'winter': 588,
#   'can': 589,
#   'memories': 590,
#   'makeup': 591,
#   'ocean': 592,
#   'ride': 593,
#   'bro': 594,
#   'travel': 595,
#   'philadelphia': 596,
#   'tour': 597,
#   'squad': 598,
#   'water': 599,
#   'are': 600,
#   'pier': 601,
#   'bff': 602,
#   'book': 603,
#   'needed': 604,
#   'ass': 605,
#   'handsome': 606,
#   'vacation': 607,
#   'minnesota': 608,
#   'photos': 609,
#   'gt': 610,
#   'drive': 611,
#   'states': 612,
#   'cause': 613,
#   'office': 614,
#   'orleans': 615,
#   "here's": 616,
#   'weeks': 617,
#   'boo': 618,
#   'spent': 619,
#   'dreams': 620,
#   'starbucks': 621,
#   'forget': 622,
#   'community': 623,
#   'enough': 624,
#   'mall': 625,
#   'nofilter': 626,
#   'thought': 627,
#   'win': 628,
#   'crew': 629,
#   'wild': 630,
#   'beer': 631,
#   'mcm': 632,
#   'by…': 633,
#   'salon': 634,
#   'h': 635,
#   'universal': 636,
#   'views': 637,
#   'behind': 638,
#   'gift': 639,
#   'station': 640,
#   'saw': 641,
#   'living': 642,
#   'em': 643,
#   'absolutely': 644,
#   'them': 645,
#   '17': 646,
#   'anyone': 647,
#   'definitely': 648,
#   'mind': 649,
#   'columbia': 650,
#   'anniversary': 651,
#   'far': 652,
#   'green': 653,
#   'golf': 654,
#   'such': 655,
#   'feels': 656,
#   'spa': 657,
#   'kitchen': 658,
#   '30': 659,
#   'hanging': 660,
#   'mood': 661,
#   "there's": 662,
#   'road': 663,
#   'senior': 664,
#   'help': 665,
#   'thursday': 666,
#   'care': 667,
#   'try': 668,
#   'share': 669,
#   'don’t': 670,
#   'kid': 671,
#   'second': 672,
#   'happiness': 673,
#   'g': 674,
#   'available': 675,
#   'wisconsin': 676,
#   'yet': 677,
#   'after': 678,
#   'kansas': 679,
#   'oregon': 680,
#   'join': 681,
#   'line': 682,
#   'tuesday': 683,
#   'mine': 684,
#   'with…': 685,
#   'her': 686,
#   'snow': 687,
#   'half': 688,
#   'pizza': 689,
#   'pics': 690,
#   'break': 691,
#   'lost': 692,
#   'hours': 693,
#   'gym': 694,
#   'about': 695,
#   'month': 696,
#   'de': 697,
#   'canyon': 698,
#   'hour': 699,
#   '20': 700,
#   'workout': 701,
#   'everyday': 702,
#   'future': 703,
#   'soul': 704,
#   'golden': 705,
#   'words': 706,
#   'seen': 707,
#   'cold': 708,
#   'avenue': 709,
#   'mama': 710,
#   'louisiana': 711,
#   'kind': 712,
#   'starting': 713,
#   'sunny': 714,
#   'woman': 715,
#   'damn': 716,
#   'nature': 717,
#   "i'd": 718,
#   'business': 719,
#   'past': 720,
#   'detroit': 721,
#   'bring': 722,
#   'cream': 723,
#   'sorry': 724,
#   'wanted': 725,
#   'fresh': 726,
#   'union': 727,
#   'catch': 728,
#   'ball': 729,
#   'bit': 730,
#   'course': 731,
#   'down': 732,
#   'air': 733,
#   'camp': 734,
#   'babies': 735,
#   'denver': 736,
#   'ok': 737,
#   'front': 738,
#   'cousin': 739,
#   '1st': 740,
#   'chicken': 741,
#   'can’t': 742,
#   'new…': 743,
#   '—': 744,
#   'charlotte': 745,
#   "she's": 746,
#   'magical': 747,
#   'casino': 748,
#   'mr': 749,
#   'drinking': 750,
#   'sushi': 751,
#   'blast': 752,
#   'evening': 753,
#   'job': 754,
#   'football': 755,
#   'star': 756,
#   'convention': 757,
#   'afternoon': 758,
#   'gets': 759,
#   'him': 760,
#   'saint': 761,
#   'eat': 762,
#   'comes': 763,
#   'pool': 764,
#   'columbus': 765,
#   'cousins': 766,
#   'this…': 767,
#   'why': 768,
#   'john': 769,
#   'losangeles': 770,
#   'ft': 771,
#   'wine': 772,
#   'omg': 773,
#   'spot': 774,
#   'double': 775,
#   'started': 776,
#   'love…': 777,
#   'nj': 778,
#   'car': 779,
#   '16': 780,
#   'group': 781,
#   'celebrate': 782,
#   'ones': 783,
#   'sea': 784,
#   'bestie': 785,
#   'da': 786,
#   'lmao': 787,
#   'earth': 788,
#   'goes': 789,
#   'experience': 790,
#   'fine': 791,
#   'was': 792,
#   'sports': 793,
#   'main': 794,
#   'ask': 795,
#   'gardens': 796,
#   'close': 797,
#   'venice': 798,
#   'harbor': 799,
#   'hate': 800,
#   'cleveland': 801,
#   'anything': 802,
#   'j': 803,
#   'missouri': 804,
#   'inn': 805,
#   'sign': 806,
#   'queen': 807,
#   'madison': 808,
#   'iowa': 809,
#   'congratulations': 810,
#   'change': 811,
#   'actually': 812,
#   'drink': 813,
#   'where': 814,
#   'wednesday': 815,
#   'its': 816,
#   'mean': 817,
#   'lots': 818,
#   'sunrise': 819,
#   'pink': 820,
#   "you're": 821,
#   'warm': 822,
#   'yoga': 823,
#   'happiest': 824,
#   'reunited': 825,
#   'oklahoma': 826,
#   'connecticut': 827,
#   'might': 828,
#   'stage': 829,
#   'sis': 830,
#   'latergram': 831,
#   'cut': 832,
#   "today's": 833,
#   'brought': 834,
#   'beat': 835,
#   'fan': 836,
#   'official': 837,
#   'daddy': 838,
#   "what's": 839,
#   'women': 840,
#   'el': 841,
#   'cheers': 842,
#   'story': 843,
#   'portland': 844,
#   'heat': 845,
#   'vote': 846,
#   'antonio': 847,
#   'quick': 848,
#   'as': 849,
#   'literally': 850,
#   'mi': 851,
#   'merica': 852,
#   'bowl': 853,
#   'yeah': 854,
#   'dope': 855,
#   '15': 856,
#   'phoenix': 857,
#   'chocolate': 858,
#   'wearing': 859,
#   'epcot': 860,
#   'running': 861,
#   'giving': 862,
#   'nevada': 863,
#   'king': 864,
#   'wishing': 865,
#   'plaza': 866,
#   'son': 867,
#   '24': 868,
#   'nc': 869,
#   'louis': 870,
#   'on…': 871,
#   'joy': 872,
#   'daughter': 873,
#   'artist': 874,
#   'liberty': 875,
#   'walking': 876,
#   'says': 877,
#   'heights': 878,
#   'am': 879,
#   'meeting': 880,
#   'body': 881,
#   'space': 882,
#   'did': 883,
#   'natural': 884,
#   'or': 885,
#   'instagram': 886,
#   'name': 887,
#   'snapchat': 888,
#   'eye': 889,
#   'so…': 890,
#   'historic': 891,
#   'mini': 892,
#   'hand': 893,
#   'boyfriend': 894,
#   'shirt': 895,
#   'area': 896,
#   'princess': 897,
#   'laugh': 898,
#   'cake': 899,
#   'dj': 900,
#   'leave': 901,
#   'camera': 902,
#   'hi': 903,
#   'talk': 904,
#   'wear': 905,
#   'tea': 906,
#   'babes': 907,
#   'smiles': 908,
#   'is…': 909,
#   'outside': 910,
#   'inc': 911,
#   'baltimore': 912,
#   'mount': 913,
#   'homecoming': 914,
#   'goals': 915,
#   'freedom': 916,
#   'sale': 917,
#   'delta': 918,
#   'must': 919,
#   'six': 920,
#   'wall': 921,
#   'delicious': 922,
#   'fuck': 923,
#   'k': 924,
#   'momma': 925,
#   'before': 926,
#   'sanfrancisco': 927,
#   'needs': 928,
#   'different': 929,
#   'books': 930,
#   'bride': 931,
#   'truly': 932,
#   'wit': 933,
#   'pa': 934,
#   'palm': 935,
#   'factory': 936,
#   'spending': 937,
#   'movie': 938,
#   'later': 939,
#   'lincoln': 940,
#   'shout': 941,
#   'use': 942,
#   'safe': 943,
#   'adventures': 944,
#   'philly': 945,
#   'honor': 946,
#   'december': 947,
#   'photoshoot': 948,
#   'wow': 949,
#   'charleston': 950,
#   'tickets': 951,
#   'told': 952,
#   'pub': 953,
#   'taken': 954,
#   'extra': 955,
#   '•••': 956,
#   'shine': 957,
#   'merrychristmas': 958,
#   'grove': 959,
#   'tavern': 960,
#   'mommy': 961,
#   'caught': 962,
#   'success': 963,
#   'monica': 964,
#   'brothers': 965,
#   'quality': 966,
#   'showing': 967,
#   'four': 968,
#   'buy': 969,
#   'cheese': 970,
#   'tag': 971,
#   'academy': 972,
#   'buffalo': 973,
#   'yo': 974,
#   'session': 975,
#   'short': 976,
#   'middle': 977,
#   'tattoo': 978,
#   '100': 979,
#   'phone': 980,
#   'mother': 981,
#   'turn': 982,
#   'rain': 983,
#   'rest': 984,
#   'bbq': 985,
#   'single': 986,
#   'pittsburgh': 987,
#   'bitch': 988,
#   'obsessed': 989,
#   'theater': 990,
#   'stuff': 991,
#   'small': 992,
#   'labor': 993,
#   'wife': 994,
#   'straight': 995,
#   'dogs': 996,
#   'surprise': 997,
#   'till': 998,
#   'utah': 999,
#   'bout': 1000,
#   ...},
#  85499)

# %%
from gensim.models.keyedvectors import KeyedVectors

# %%
embeddings_index = {}
f = open('glove.6B.300d.txt','r',encoding='utf-8')
for line in f:
    values = line.split(' ')
    word = values[0]
    coefs = np.asarray([float(val) for val in values[1:]])
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
weight_matrix = create_weight_matrix(vocab, embeddings_index)
len(weight_matrix)
# Out:
# 85500

# %%
model, score, acc = final_model(weight_matrix, len(vocab)+1, max_length, x, y, epochs = 5)
model, score, acc
# Out:
# Epoch 1/5
# 1149/1149 [==============================] - 487s 412ms/step - loss: 2.3366 - accuracy: 0.3100 - val_loss: 2.2312 - val_accuracy: 0.3395
# Epoch 2/5
# 1149/1149 [==============================] - 471s 410ms/step - loss: 1.8467 - accuracy: 0.4426 - val_loss: 2.3291 - val_accuracy: 0.3390
# Epoch 3/5
# 1149/1149 [==============================] - 458s 398ms/step - loss: 1.1108 - accuracy: 0.6608 - val_loss: 2.7927 - val_accuracy: 0.2978
# Epoch 4/5
# 1149/1149 [==============================] - 494s 430ms/step - loss: 0.6324 - accuracy: 0.8054 - val_loss: 3.3959 - val_accuracy: 0.2869
# Epoch 5/5
#  624/1149 [===============>..............] - ETA: 3:49 - loss: 0.3852 - accuracy: 0.8823

# %%
model.summary
